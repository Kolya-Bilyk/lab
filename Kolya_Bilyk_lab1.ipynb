# %% [markdown]
# <a href="https://colab.research.google.com/github/Kolya-Bilyk/lab/blob/master/Kolya_Bilyk_lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
im1=cv2.imread("1.jpg",cv2.IMREAD_GRAYSCALE)
im1=cv2.cvtColor(im1,cv2.COLOR_BGR2RGB)
im2=cv2.imread("4.jpg",cv2.IMREAD_COLOR)
im2_1=cv2.cvtColor(im2,cv2.COLOR_BGR2RGB)
im2_2=cv2.cvtColor(im2,cv2.COLOR_BGR2HSV)

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %%
plt.figure(figsize=(5,5))
plt.imshow(im1)
plt.show()
plt.figure(figsize=(5,5))
plt.imshow(im2_1)
plt.show()
plt.figure(figsize=(5,5))
plt.imshow(im2_2)
plt.show()

# %%
plt.figure(figsize=(10, 10))

b, g, r = cv2.split(im2_1)
plt.subplot(131);
R = np.zeros(im2_1.shape, dtype='uint8')
R[:, :, 0] = r
plt.imshow(R)

plt.subplot(132);
G = np.zeros(im2_1.shape, dtype='uint8')
G[:, :, 1] = g
plt.imshow(G)

plt.subplot(133);
B = np.zeros(im2_1.shape, dtype='uint8')
B[:, :, 2] = b
plt.imshow(B)

plt.figure(figsize=(10,10))

h, s, v =cv2.split(im2_2)
plt.subplot(131)
H = np.zeros(im2_2.shape, dtype='uint8')
H[:, :, 0] = h
plt.imshow(H)

plt.subplot(132);
S = np.zeros(im2_2.shape, dtype='uint8')
S[:, :, 1] = s
plt.imshow(S)

plt.subplot(133);
V = np.zeros(im2_2.shape, dtype='uint8')
V[:, :, 2] = v
plt.imshow(V)

plt.show()

# %%
 x=im1.shape[0]/2 
 y=im1.shape[1]/2
 im_crop=im1[0:int(x),0:int(y)]
 plt.imshow(im_crop)
 plt.show()

# %%
cv2.imwrite("./im_crop.png", im_crop)
# Out:
# True
